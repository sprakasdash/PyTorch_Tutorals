# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2020-05-20 13:01:39--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2020-05-20 13:01:40--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2020-05-20 13:01:41--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  2.18MB/s    in 6m 29s
#
# 2020-05-20 13:08:10 (2.11 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]

# %%
# !unzip glove.6B.zip
# Out:
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
# !unzip glove.6B.zip
# !pip install conllu
# !pip install spacy
# !pip install spacy-conll==1.3.0
# !git clone https://github.com/pasinit/nlp2020_POStagging_data.git
# !unzip nlp2020_POStagging_data/r2.2.zip  > /dev/null
# !rm -rf nlp2020_POStagging_data/
# Out:
# Collecting conllu
#   Downloading https://files.pythonhosted.org/packages/a8/03/4a952eb39cdc8da80a6a2416252e71784dda6bf9d726ab98065fff2aeb73/conllu-2.3.2-py2.py3-none-any.whl
# Installing collected packages: conllu
# Successfully installed conllu-2.3.2
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (3.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.6.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.18.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (46.3.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.1.0)
# Collecting spacy-conll==1.3.0
#   Downloading https://files.pythonhosted.org/packages/16/43/8e979338259a0e8e1881d7cfc01d4fbc16bc43d89a00151a367a1e821be8/spacy_conll-1.3.0-py3-none-any.whl
# Requirement already satisfied: spacy>=2.0 in /usr/local/lib/python3.6/dist-packages (from spacy-conll==1.3.0) (2.2.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from spacy-conll==1.3.0) (20.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (2.0.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (4.41.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (46.3.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (1.0.2)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (3.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (1.18.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0->spacy-conll==1.3.0) (1.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->spacy-conll==1.3.0) (1.12.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->spacy-conll==1.3.0) (2.4.7)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.0->spacy-conll==1.3.0) (1.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0->spacy-conll==1.3.0) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0->spacy-conll==1.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0->spacy-conll==1.3.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0->spacy-conll==1.3.0) (2.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.0->spacy-conll==1.3.0) (3.1.0)
# Installing collected packages: spacy-conll
# Successfully installed spacy-conll-1.3.0

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (46.3.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.6.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.18.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2020.4.5.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import torch
from torch import nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.optim as optim
# from torchtext import data
# from torchtext.vocab import Vectors
from collections import defaultdict
from conllu import parse as conllu_parse
from pprint import pprint
from tqdm import tqdm
# from torchtext.vocab import Vocab
from collections import Counter
import csv
import random
import numpy as np
import spacy
from spacy_conll import ConllFormatter
from spacy_conll import Spacy2ConllParser
SEED = 123456

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
# from torchtext.vocab import Vocab

# %%
training_file = "drive/My Drive/NLP_Assignment/train.tsv"
dev_file = "drive/My Drive/NLP_Assignment/dev.tsv"
test_file = "drive/My Drive/NLP_Assignment/test.tsv"

# %%
# TSV & CONLLU
def file2str(file_o):
    input_str = list()
    with open(test_file) as tsvfile:
        tsvreader = csv.reader(tsvfile, delimiter="#")
        for line in tsvreader:
            if(len(line[1:]) != 0):
                input_str.append(line[1:][0][1:])
    return ' '.join(input_str)

train_str = file2str(training_file)
dev_str = file2str(dev_file)
test_str = file2str(test_file)

spacyconll = Spacy2ConllParser()
spacyconll.parseprint(input_str=''.join(train_str), output_file="train.conllu")
spacyconll.parseprint(input_str=''.join(dev_str), output_file="dev.conllu")
spacyconll.parseprint(input_str=''.join(test_str), output_file="test.conllu")

# %%
class man_made_Vocab(object):
    
    UNK = "<unk>"
    
    def __init__(self, counter, min_freq=1, specials=['<unk>', '<pad>']):
        
        counter = counter.copy()
        self.itos = list()
        self.unk_index = None
        self.itos = list(specials)
        
        for tok in specials:
            del counter[tok]
            
        words_and_frequencies = sorted(counter.items(), key=lambda tup: tup[0])
        words_and_frequencies.sort(key=lambda tup: tup[1], reverse=True)
        
        for word, freq in words_and_frequencies:
            self.itos.append(word)
        
        if man_made_Vocab.UNK in specials:
            unk_index = specials.index(man_made_Vocab.UNK)
            self.unk_index = unk_index
            self.stoi = defaultdict(self._default_unk_index)
        else:
            self.stoi = defaultdict()
        
        self.stoi.update({tok: i for i, tok in enumerate(self.itos)})
        
    def _default_unk_index(self):
        return self.unk_index

    def __getstate__(self):
        # avoid picking defaultdict
        attrs = dict(self.__dict__)
        # cast to regular dict
        attrs['stoi'] = dict(self.stoi)
        return attrs

    def __setstate__(self, state):
        if state.get("unk_index", None) is None:
            stoi = defaultdict()
        else:
            stoi = defaultdict(self._default_unk_index)
        stoi.update(state['stoi'])
        state['stoi'] = stoi
        self.__dict__.update(state)
    
    def __getitem__(self, token):
        return self.stoi.get(token, self.stoi.get(man_made_Vocab.UNK))
        
    def __len__(self):
        return len(self.itos)

# %%
class POSTaggingDataset(Dataset):

    def __init__(self, 
                 input_file:str, 
                 window_size:int, 
                 window_shift:int=-1,
                 lowercase=True, 
                 device="cpu"):
        """
        We assume that the dataset pointed by input_file is already tokenized 
        and can fit in memory.
        Args:
            input_file (string): The path to the dataset to be loaded.
            window_size (integer): The maximum length of a sentence in terms of 
            number of tokens.
            window_shift (integer): The number of tokens we shift the window 
            over the sentence. Default value is -1 meaning that the window will
            be shifted by window_size.
            lowercase (boolean): whether the text has to be lowercased or not.
            device (string): device where to put tensors (cpu or cuda).
        """

        self.input_file = input_file
        self.window_size = window_size
        self.window_shift = window_shift if window_shift > 0 else window_size
        self.lowercase = lowercase
        with open(input_file) as reader:
            # read the entire file with reader.read() e parse it
            sentences = conllu_parse(reader.read())
        self.device = device
        self.data = self.create_windows(sentences)
        self.encoded_data = None
    
    def index_dataset(self, l_vocabulary, l_label_vocabulary):
        self.encoded_data = list()
        for i in range(len(self.data)):
            # for each window
            elem = self.data[i]
            encoded_elem = torch.LongTensor(self.encode_text(elem, l_vocabulary)).to(self.device)
            # for each element d in the elem window (d is a dictionary with the various fields from the CoNLL line) 
            encoded_labels = torch.LongTensor([l_label_vocabulary.stoi[d["upostag"]] if d is not None 
                              else l_label_vocabulary.stoi["<pad>"] for d in elem]).to(self.device)
            self.encoded_data.append({"inputs":encoded_elem, "outputs":encoded_labels})

    def create_windows(self, sentences):
        """ 
        Args:
            sentences (list of lists of dictionaries, 
                          where each dictionary represents a word occurrence parsed from a CoNLL line)
        """
        data = []
        for sentence in sentences:
            if self.lowercase:
                for d in sentence:
                    # lowers the inflected form
                    d["form"] = d["form"].lower()
            for i in range(0, len(sentence), self.window_shift):
                window = sentence[i:i+self.window_size]
                if len(window) < self.window_size:
                    window = window + [None]*(self.window_size - len(window))
                assert len(window) == self.window_size
                data.append(window)
        return data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if self.encoded_data is None:
            raise RuntimeError("""Trying to retrieve elements but index_dataset
            has not been invoked yet! Be sure to invoce index_dataset on this object
            before trying to retrieve elements. In case you want to retrieve raw
            elements, use the method get_raw_element(idx)""")
        return self.encoded_data[idx]
    
    def get_raw_element(self, idx):
        return self.data[idx]

    @staticmethod
    def encode_text(sentence:list, l_vocabulary):
        """
        Args:
            sentences (list): list of OrderedDict, each carrying the information about
            one token.
            l_vocabulary (Vocab): vocabulary with mappings from words to indices and viceversa.
        Return:
            The method returns a list of indices corresponding to the input tokens.
        """
        indices = list()
        for w in sentence:
            if w is None:
                indices.append(l_vocabulary.stoi["<pad>"])
            elif w["form"] in l_vocabulary.stoi: # vocabulary string to integer
                indices.append(l_vocabulary.stoi[w["form"]])
            else:
                indices.append(l_vocabulary.stoi["<unk>"])
        return indices
    
    @staticmethod
    def decode_output(outputs:torch.Tensor,
                    l_label_vocabulary):
        """
        Args:
            outputs (Tensor): a Tensor with shape (batch_size, max_len, label_vocab_size)
                containing the logits outputed by the neural network.
            l_label_vocabulary (Vocab): is the vocabulary containing the mapping from
            a string label to its corresponding index and vice versa
        Output:
            The method returns a list of batch_size length where each element is a list
            of labels, one for each input token.
        """
        max_indices = torch.argmax(outputs, -1).tolist() # shape = (batch_size, max_len)
        predictions = list()
        print(max_indices)
        for indices in max_indices:
            # vocabulary integer to string is used to obtain the corresponding word from the max index
            predictions.append([l_label_vocabulary.itos[i] for i in indices])
        print(predictions)
        return predictions

# %%
def build_vocab(dataset, min_freq=1):
    counter = Counter()
    for i in tqdm(range(len(dataset))):
        # for each token in the sentence viewed as a dictionary of items from the CoNLL line
        for token in dataset.get_raw_element(i):
            if token is not None:
                counter[token["form"]]+=1
    # we add special tokens for handling padding and unknown words at testing time.
    return man_made_Vocab(counter, min_freq=min_freq, specials=['<pad>', '<unk>'])

def build_label_vocab(dataset):
    counter = Counter()
    for i in tqdm(range(len(dataset))):
        for token in dataset.get_raw_element(i):
            if token is not None:
                counter[token["upostag"]]+=1
    # No <unk> token for labels.
    return man_made_Vocab(counter, specials=['<pad>'])

# %%
window_size, window_shift = 100, 100
dataset = POSTaggingDataset("train.conllu", window_size, window_shift)
vocabulary = build_vocab(dataset, min_freq=2)
label_vocabulary = build_label_vocab(dataset)
dataset.index_dataset(vocabulary, label_vocabulary)
print(len(vocabulary))
print(len(label_vocabulary))
# Out:
# 100%|██████████| 16016/16016 [00:00<00:00, 49367.38it/s]
# 100%|██████████| 16016/16016 [00:00<00:00, 73467.43it/s]
# 34798
# 18

# %%
class POSTaggerModel(nn.Module):
    # we provide the hyperparameters as input
    def __init__(self, hparams):
        super(POSTaggerModel, self).__init__()
        # Embedding layer: a mat∂rix vocab_size x embedding_dim where each index 
        # correspond to a word in the vocabulary and the i-th row corresponds to 
        # a latent representation of the i-th word in the vocabulary.
        pprint(params)
        self.word_embedding = nn.Embedding(hparams.vocab_size, hparams.embedding_dim)
        if hparams.embeddings is not None:
            print("initializing embeddings from pretrained")
            self.word_embedding.weight.data.copy_(hparams.embeddings)

        # LSTM layer: an LSTM neural network that process the input text
        # (encoded with word embeddings) from left to right and outputs 
        # a new **contextual** representation of each word that depend
        # on the preciding words.
        self.lstm = nn.LSTM(hparams.embedding_dim, hparams.hidden_dim, 
                            bidirectional=hparams.bidirectional,
                            num_layers=hparams.num_layers, 
                            dropout = hparams.dropout if hparams.num_layers > 1 else 0)
        # Hidden layer: transforms the input value/scalar into
        # a hidden vector representation.
        lstm_output_dim = hparams.hidden_dim if hparams.bidirectional is False else hparams.hidden_dim * 2

        # During training, randomly zeroes some of the elements of the 
        # input tensor with probability hparams.dropout using samples 
        # from a Bernoulli distribution. Each channel will be zeroed out 
        # independently on every forward call.
        # This has proven to be an effective technique for regularization and 
        # preventing the co-adaptation of neurons
        self.dropout = nn.Dropout(hparams.dropout)
        self.classifier = nn.Linear(lstm_output_dim, hparams.num_classes)

    
    def forward(self, x):
        embeddings = self.word_embedding(x)
        embeddings = self.dropout(embeddings)
        o, (h, c) = self.lstm(embeddings)
        o = self.dropout(o)
        output = self.classifier(o)
        return output

# %%
class Trainer():
    """Utility class to train and evaluate a model."""

    def __init__(
        self,
        model: nn.Module,
        loss_function,
        optimizer,
        label_vocab,
        log_steps:int=10_000,
        log_level:int=2):
        """
        Args:
            model: the model we want to train.
            loss_function: the loss_function to minimize.
            optimizer: the optimizer used to minimize the loss_function.
        """
        self.model = model
        self.loss_function = loss_function
        self.optimizer = optimizer

        self.label_vocab = label_vocab
        self.log_steps = log_steps
        self.log_level = log_level
        self.label_vocab = label_vocab

    def train(self, train_dataset:Dataset, 
              valid_dataset:Dataset, 
              epochs:int=1):
        """
        Args:
            train_dataset: a Dataset or DatasetLoader instance containing
                the training instances.
            valid_dataset: a Dataset or DatasetLoader instance used to evaluate
                learning progress.
            epochs: the number of times to iterate over train_dataset.

        Returns:
            avg_train_loss: the average training loss on train_dataset over
                epochs.
        """
        assert epochs > 1 and isinstance(epochs, int)
        if self.log_level > 0:
            print('Training ...')
        train_loss = 0.0
        for epoch in range(epochs):
            if self.log_level > 0:
                print(' Epoch {:03d}'.format(epoch + 1))

            epoch_loss = 0.0
            self.model.train()

            for step, sample in enumerate(train_dataset):
                inputs = sample['inputs']
                labels = sample['outputs']
                self.optimizer.zero_grad()

                predictions = self.model(inputs)
                predictions = predictions.view(-1, predictions.shape[-1])
                labels = labels.view(-1)
                
                sample_loss = self.loss_function(predictions, labels)
                sample_loss.backward()
                self.optimizer.step()

                epoch_loss += sample_loss.tolist()

                if self.log_level > 1 and step % self.log_steps == self.log_steps - 1:
                    print('\t[E: {:2d} @ step {}] current avg loss = {:0.4f}'.format(epoch, step, epoch_loss / (step + 1)))
            
            avg_epoch_loss = epoch_loss / len(train_dataset)
            train_loss += avg_epoch_loss
            if self.log_level > 0:
                print('\t[E: {:2d}] train loss = {:0.4f}'.format(epoch, avg_epoch_loss))

            valid_loss = self.evaluate(valid_dataset)
            
            if self.log_level > 0:
                print('  [E: {:2d}] valid loss = {:0.4f}'.format(epoch, valid_loss))

        if self.log_level > 0:
            print('... Done!')
        
        avg_epoch_loss = train_loss / epochs
        return avg_epoch_loss
    

    def evaluate(self, valid_dataset):
        """
        Args:
            valid_dataset: the dataset to use to evaluate the model.

        Returns:
            avg_valid_loss: the average validation loss over valid_dataset.
        """
        valid_loss = 0.0
        # set dropout to 0!! Needed when we are in inference mode.
        self.model.eval()
        with torch.no_grad():
            for sample in valid_dataset:
                inputs = sample['inputs']
                labels = sample['outputs']

                predictions = self.model(inputs)
                predictions = predictions.view(-1, predictions.shape[-1])
                labels = labels.view(-1)
                sample_loss = self.loss_function(predictions, labels)
                valid_loss += sample_loss.tolist()
        
        return valid_loss / len(valid_dataset)

    def predict(self, x):
        """
        Args:
            x: a tensor of indices.
        Returns: 
            A list containing the predicted POS tag for each token in the
            input sentences.
        """
        self.model.eval()
        with torch.no_grad():
            logits = self.model(x)
            predictions = torch.argmax(logits, -1)
            return logits, predictions

# %%
class HParams():
    vocab_size = len(vocabulary)
    hidden_dim = 256
    embedding_dim = 100
    num_classes = len(label_vocabulary) # number of different universal POS tags
    bidirectional = True
    num_layers = 2
    dropout = 0.0
    embeddings = None
params = HParams()

# %%
# import os
# vectors = Vectorization("glove.6B.100d.txt")
embeddings_dict = {}
with open("glove.6B.100d.txt", 'r', encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
# len(embeddings_dict['feel'])
# embeddings_dict

# %%
# import os
# vectors = Vectorization("glove.6B.100d.txt")
pretrained_embeddings = torch.randn(len(vocabulary), len(embeddings_dict['a']))
initialised = 0
for i, w in enumerate(vocabulary.itos):
    if w in embeddings_dict:
        initialised += 1
        vec = torch.from_numpy(embeddings_dict[w]) #vectors.get_vecs_by_tokens(w)
        pretrained_embeddings[i] = vec
    
pretrained_embeddings[vocabulary["<pad>"]] = torch.zeros(len(embeddings_dict['a']))
params.embedding_dim=len(embeddings_dict['a'])
params.embeddings = pretrained_embeddings
params.vocab_size = len(vocabulary)

# %%
window_size, window_shift = 100, 100
device = "cpu"
trainingset = POSTaggingDataset("train.conllu", window_size, window_shift, device=device)
vocabulary = build_vocab(trainingset, min_freq=2)
label_vocabulary = build_label_vocab(trainingset)
trainingset.index_dataset(vocabulary, label_vocabulary)

devset = POSTaggingDataset("dev.conllu", window_size, window_shift, device=device)
vocabulary = build_vocab(devset, min_freq=2)
label_vocabulary = build_label_vocab(devset)
devset.index_dataset(vocabulary, label_vocabulary)

testset = POSTaggingDataset("test.conllu", window_size, window_shift, device=device)
vocabulary = build_vocab(testset, min_freq=2)
label_vocabulary = build_label_vocab(testset)
testset.index_dataset(vocabulary, label_vocabulary)

train_dataset = DataLoader(trainingset, batch_size=128)
valid_dataset = DataLoader(devset, batch_size=128)
test_dataset = DataLoader(testset, batch_size=128)

postagger = POSTaggerModel(params)#.cuda()
# Out:
# 100%|██████████| 16016/16016 [00:00<00:00, 47510.04it/s]
# 100%|██████████| 16016/16016 [00:00<00:00, 66592.82it/s]
# 100%|██████████| 16016/16016 [00:00<00:00, 48276.81it/s]
# 100%|██████████| 16016/16016 [00:00<00:00, 67327.12it/s]
# 100%|██████████| 16016/16016 [00:00<00:00, 47111.31it/s]
# 100%|██████████| 16016/16016 [00:00<00:00, 68467.75it/s]
# <__main__.HParams object at 0x7fefe3e6ec50>
# initializing embeddings from pretrained

# %%
bilstm_trainer = Trainer(
    model = postagger,
    loss_function = nn.CrossEntropyLoss(ignore_index=label_vocabulary["<pad>"]),
    optimizer = optim.Adam(postagger.parameters()),
    label_vocab=label_vocabulary
)

# %%
bilstm_trainer.train(train_dataset, valid_dataset, 10)
# Out:
# Training ...
#  Epoch 001
# 	[E:  0] train loss = 0.9793
#   [E:  0] valid loss = 0.3146
#  Epoch 002
# 	[E:  1] train loss = 0.2720
#   [E:  1] valid loss = 0.2304
#  Epoch 003
# 	[E:  2] train loss = 0.2235
#   [E:  2] valid loss = 0.1990
#  Epoch 004
# 	[E:  3] train loss = 0.2006
#   [E:  3] valid loss = 0.1836
#  Epoch 005
# 	[E:  4] train loss = 0.1850
#   [E:  4] valid loss = 0.1705
#  Epoch 006
# 	[E:  5] train loss = 0.1730
#   [E:  5] valid loss = 0.1581
#  Epoch 007
# 	[E:  6] train loss = 0.1616
#   [E:  6] valid loss = 0.1466
#  Epoch 008
# 	[E:  7] train loss = 0.1496
#   [E:  7] valid loss = 0.1342
#  Epoch 009
# 	[E:  8] train loss = 0.1363
#   [E:  8] valid loss = 0.1208
#  Epoch 010
# 	[E:  9] train loss = 0.1213
#   [E:  9] valid loss = 0.1074
# ... Done!
# 0.2602300394622107

# %%
torch.save(postagger.state_dict(), "postagger.pth")

# %%
from sklearn.metrics import precision_score as sk_precision
def compute_precision(model, l_dataset, l_label_vocab):
    all_predictions = list()
    all_labels = list()
    for indexed_elem in l_dataset:
        indexed_in = indexed_elem["inputs"]
        indexed_labels = indexed_elem["outputs"]
        predictions = model(indexed_in)
        predictions = torch.argmax(predictions, -1).view(-1)
        labels = indexed_labels.view(-1)
        valid_indices = labels != 0
        
        valid_predictions = predictions[valid_indices]
        valid_labels = labels[valid_indices]
        
        all_predictions.extend(valid_predictions.tolist())
        all_labels.extend(valid_labels.tolist())
    # global precision. Does take class imbalance into account.
    micro_precision = sk_precision(all_labels, all_predictions, average="micro", zero_division=0)
    # precision per class and arithmetic average of them. Does not take into account class imbalance.
    macro_precision = sk_precision(all_labels, all_predictions, average="macro", zero_division=0)
    per_class_precision = sk_precision(all_labels, all_predictions, labels = list(range(len(l_label_vocab))), average=None, zero_division=0)
    
    return {"micro_precision":micro_precision,
            "macro_precision":macro_precision, 
            "per_class_precision":per_class_precision}

# %%
precisions = compute_precision(postagger, test_dataset, label_vocabulary)
per_class_precision = precisions["per_class_precision"]
print("Micro Precision: {}\nMacro Precision: {}".format(precisions["micro_precision"], precisions["macro_precision"]))
print("Per class Precision:")
for idx_class, precision in sorted(enumerate(per_class_precision), key=lambda elem: -elem[1]):
    label = label_vocabulary.itos[idx_class]
    print(label, precision)

# %%
test_set_loss = bilstm_trainer.evaluate(test_dataset)
print("test set loss: {}".format(test_set_loss))

# %%
def print_outputs(l_trainer, l_testset, num_outputs, l_vocabulary, l_label_vocabulary):
    
    for i in range(num_outputs):
        print("sentence {}".format(i))
        print()
        test_elem = l_testset[i]

        test_x, test_y = test_elem["inputs"], test_elem["outputs"]
        
        logits, predictions = l_trainer.predict(test_x.unsqueeze(0))
        print(l_label_vocabulary.itos)
        decoded_labels = POSTaggingDataset.decode_output(logits, l_label_vocabulary)[0]
        test_y = test_y.tolist()
        print("token\t\tinput\t\tgold\t\tprediction")
        print("-"*100)
        for raw_elem, idx, label, predicted_label in zip(l_testset.get_raw_element(i), test_x.tolist(), test_y, decoded_labels):
            if idx == 0:
                break
            print("{}\t\t{}\t\t{}\t\t{}".format(raw_elem["form"], l_vocabulary.itos[idx], l_label_vocabulary.itos[label], predicted_label))
        print("="*30)

print_outputs(bilstm_trainer, testset, 10, vocabulary, label_vocabulary)

# %%
def print_outputs(l_trainer, l_testset, l_vocabulary, l_label_vocabulary):

    test_elem = l_testset[0]

    # test_x, test_y = test_elem["inputs"], test_elem["outputs"]
    test_x = test_elem["inputs"]
    logits, predictions = l_trainer.predict(test_x.unsqueeze(0))
        
    decoded_labels = POSTaggingDataset.decode_output(logits, l_label_vocabulary)[0]
    # test_y = test_y.tolist()
    print("token\t\tinput\t\tprediction")
    print("-"*100)
    for raw_elem, idx, predicted_label in zip(l_testset.get_raw_element(0),test_x.tolist(), decoded_labels):  #, test_y,
        if idx == 0:
            break
        print("{}\t\t{}\t\t{}".format(raw_elem["form"], l_vocabulary.itos[idx], predicted_label)) # l_label_vocabulary.itos[label],
    print("="*30)

print_outputs(bilstm_trainer, testset, vocabulary, label_vocabulary)
# Out:
# token		input		prediction
# ----------------------------------------------------------------------------------------------------
#  		 		DET
# however		however		CCONJ
# ,		,		CCONJ
# on		on		CCONJ
# may		may		CCONJ
# 8th		8th		DET
# ,		,		CCONJ
# 2010		2010		DET
# ,		,		CCONJ
# a		a		CCONJ
# sighting		sighting		DET
# of		of		CCONJ
# a		a		CCONJ
# gray		gray		CCONJ
# whale		whale		DET
# was		was		CCONJ
# confirmed		confirmed		CCONJ
# off		off		CCONJ
# the		the		CCONJ
# coast		coast		CCONJ
# of		of		CCONJ
# israel		israel		CCONJ
# in		in		CCONJ
# the		the		CCONJ
# mediterranean		mediterranean		CCONJ
# sea		sea		CCONJ
# .		.		CCONJ
# ,		,		CCONJ
# leading		leading		CCONJ
# some		some		CCONJ
# scientists		scientists		CCONJ
# to		to		CCONJ
# think		think		CCONJ
# they		they		CCONJ
# might		might		CCONJ
# be		be		CCONJ
# repopulating		repopulating		DET
# old		old		CCONJ
# breeding		breeding		DET
# grounds		grounds		CCONJ
# that		that		CCONJ
# have		have		CCONJ
# not		not		CCONJ
# been		been		CCONJ
# used		used		DET
# for		for		CCONJ
# centuries		centuries		CCONJ
# .		.		CCONJ
# ==============================

# %%
def print_outputs(l_trainer, l_testset, l_vocabulary, l_label_vocabulary):
    
    for i in range(len(test_str)):
        print("sentence {}".format(i))
        print()
        test_elem = l_testset[i]

        test_x, test_y = test_elem["inputs"], test_elem["outputs"]
        
        logits, predictions = l_trainer.predict(test_x.unsqueeze(0))
        
        decoded_labels = POSTaggingDataset.decode_output(logits, l_label_vocabulary)[0]
        test_y = test_y.tolist()
        print("token\t\tinput\t\tgold\t\tprediction")
        print("-"*100)
        for raw_elem, idx, label, predicted_label in zip(l_testset.get_raw_element(i), test_x.tolist(), test_y, decoded_labels):
            if idx == 0:
                break
            print("{}\t\t{}\t\t{}\t\t{}".format(raw_elem["form"], l_vocabulary.itos[idx], l_label_vocabulary.itos[label], predicted_label))
        print("="*30)

print_outputs(bilstm_trainer, testset, vocabulary, label_vocabulary)
# Out:
# Streaming output truncated to the last 5000 lines.
# opponents		opponents		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# successfully		successfully		ADV		CCONJ
# prevented		prevented		VERB		CCONJ
# their		their		DET		CCONJ
# violent		violent		ADJ		CCONJ
# measures		measures		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15304
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# economic		economic		ADJ		CCONJ
# output		output		NOUN		CCONJ
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# gaza		gaza		PROPN		CCONJ
# strip		strip		PROPN		CCONJ
# declined		declined		VERB		CCONJ
# by		by		ADP		CCONJ
# about		about		ADV		CCONJ
# one-third		one-third		NOUN		DET
# between		between		ADP		CCONJ
# 1992		1992		NUM		CCONJ
# and		and		CCONJ		CCONJ
# 1996		1996		NUM		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15305
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# esoterist		esoterist		ADJ		CCONJ
# views		views		NOUN		CCONJ
# revelation		revelation		NOUN		DET
# as		as		SCONJ		CCONJ
# bearing		bearing		VERB		CCONJ
# multiple		multiple		ADJ		CCONJ
# levels		levels		NOUN		CCONJ
# of		of		ADP		CCONJ
# meaning		meaning		NOUN		DET
# ,		,		PUNCT		CCONJ
# ==============================
# sentence 15306
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# lowest		lowest		ADJ		CCONJ
# being		being		AUX		CCONJ
# the		the		DET		CCONJ
# literal		literal		ADJ		DET
# or		or		CCONJ		CCONJ
# "		"		PUNCT		CCONJ
# dead-letter		dead-letter		ADJ		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15307
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# "		"		PUNCT		CCONJ
# it		it		PRON		CCONJ
# also		also		ADV		DET
# organised		organised		VERB		DET
# a		a		DET		CCONJ
# vigil		vigil		NOUN		CCONJ
# for		for		ADP		CCONJ
# the		the		DET		CCONJ
# victims		victims		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# 2005		2005		NUM		CCONJ
# london		london		PROPN		CCONJ
# bombings		bombings		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15308
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# on		on		ADP		CCONJ
# june		june		PROPN		CCONJ
# 12		12		NUM		CCONJ
# ,		,		PUNCT		CCONJ
# 1995		1995		NUM		CCONJ
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# indians		indians		PROPN		DET
# began		began		VERB		CCONJ
# a		a		DET		CCONJ
# record-breaking		record-breaking		ADJ		DET
# 455-game		455-game		NUM		CCONJ
# home		home		NOUN		CCONJ
# sellout		sellout		NOUN		CCONJ
# streak		streak		NOUN		CCONJ
# that		that		DET		CCONJ
# did		did		AUX		CCONJ
# not		not		PART		CCONJ
# end		end		VERB		CCONJ
# until		until		ADP		CCONJ
# april		april		PROPN		CCONJ
# 4		4		NUM		CCONJ
# ,		,		PUNCT		CCONJ
# 2001		2001		NUM		DET
# ,		,		PUNCT		CCONJ
# almost		almost		ADV		CCONJ
# six		six		NUM		CCONJ
# years		years		NOUN		CCONJ
# later		later		ADV		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15309
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# wright		wright		PROPN		CCONJ
# 's		's		PART		CCONJ
# autobiography		autobiography		NOUN		DET
# talks		talks		VERB		CCONJ
# about		about		ADP		CCONJ
# the		the		DET		CCONJ
# influence		influence		NOUN		CCONJ
# of		of		ADP		CCONJ
# these		these		DET		CCONJ
# exercises		exercises		NOUN		CCONJ
# on		on		ADP		CCONJ
# his		his		DET		CCONJ
# approach		approach		NOUN		CCONJ
# to		to		ADP		CCONJ
# design		design		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15310
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# kelsey		kelsey		PROPN		DET
# grammer		grammer		PROPN		DET
# acknowledged		acknowledged		VERB		CCONJ
# the		the		DET		CCONJ
# creative		creative		ADJ		CCONJ
# lull		lull		NOUN		DET
# ,		,		PUNCT		CCONJ
# saying		saying		VERB		CCONJ
# that		that		SCONJ		CCONJ
# over		over		ADP		CCONJ
# the		the		DET		CCONJ
# course		course		NOUN		CCONJ
# of		of		ADP		CCONJ
# two		two		NUM		CCONJ
# later		later		ADJ		CCONJ
# seasons		seasons		NOUN		DET
# the		the		DET		CCONJ
# show		show		NOUN		CCONJ
# "		"		PUNCT		CCONJ
# took		took		VERB		CCONJ
# itself		itself		PRON		CCONJ
# too		too		ADV		CCONJ
# seriously		seriously		ADV		CCONJ
# "		"		PUNCT		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15311
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# this		this		DET		CCONJ
# design-based		design-based		ADJ		DET
# analysis		analysis		NOUN		CCONJ
# was		was		AUX		CCONJ
# discussed		discussed		VERB		CCONJ
# and		and		CCONJ		CCONJ
# developed		developed		VERB		DET
# by		by		ADP		CCONJ
# francis		francis		PROPN		DET
# j.		j.		PROPN		CCONJ
# anscombe		anscombe		PROPN		DET
# at		at		ADP		CCONJ
# rothamsted		rothamsted		PROPN		DET
# experimental		experimental		PROPN		CCONJ
# station		station		PROPN		CCONJ
# and		and		CCONJ		CCONJ
# by		by		ADP		CCONJ
# oscar		oscar		PROPN		CCONJ
# kempthorne		kempthorne		PROPN		DET
# at		at		ADP		CCONJ
# iowa		iowa		PROPN		CCONJ
# state		state		PROPN		CCONJ
# university		university		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15312
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# at		at		ADP		CCONJ
# that		that		DET		CCONJ
# moment		moment		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# however		however		ADV		CCONJ
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# other		other		ADJ		CCONJ
# conspirators		conspirators		NOUN		CCONJ
# arrived		arrived		VERB		CCONJ
# and		and		CCONJ		CCONJ
# fired		fired		VERB		CCONJ
# at		at		ADP		CCONJ
# rasputin		rasputin		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15313
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# peter		peter		PROPN		CCONJ
# šťastný		šťastný		PROPN		DET
# ,		,		PUNCT		CCONJ
# jaromír		jaromír		PROPN		DET
# jágr		jágr		PROPN		DET
# ,		,		PUNCT		CCONJ
# peter		peter		PROPN		CCONJ
# bondra		bondra		PROPN		DET
# ,		,		PUNCT		CCONJ
# marián		marián		PROPN		DET
# gáborík		gáborík		PROPN		DET
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# pavol		pavol		PROPN		DET
# demitra		demitra		PROPN		DET
# all		all		DET		CCONJ
# come		come		VERB		CCONJ
# from		from		ADP		CCONJ
# czechoslovakia		czechoslovakia		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15314
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# he		he		PRON		CCONJ
# was		was		AUX		CCONJ
# played		played		VERB		CCONJ
# by		by		ADP		CCONJ
# one		one		NUM		CCONJ
# of		of		ADP		CCONJ
# hungary		hungary		PROPN		DET
# 's		's		PART		CCONJ
# most		most		ADV		CCONJ
# renowned		renowned		ADJ		CCONJ
# actors		actors		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# ivan		ivan		PROPN		CCONJ
# darvas		darvas		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15315
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# subsequent		subsequent		ADJ		CCONJ
# u.s.		u.s.		PROPN		CCONJ
# jet		jet		NOUN		CCONJ
# fighter		fighter		NOUN		CCONJ
# designs		designs		NOUN		CCONJ
# have		have		AUX		CCONJ
# more		more		ADV		CCONJ
# modest		modest		ADJ		CCONJ
# tilt-back		tilt-back		ADJ		DET
# angles		angles		NOUN		DET
# of		of		ADP		CCONJ
# 20°		20°		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15316
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# flight		flight		NOUN		CCONJ
# 77		77		NUM		CCONJ
# 's		's		PART		CCONJ
# flightpath		flightpath		NOUN		CCONJ
# cuts		cuts		NOUN		CCONJ
# directly		directly		ADV		CCONJ
# through		through		ADP		CCONJ
# the		the		DET		CCONJ
# park		park		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15317
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# tournament		tournament		NOUN		CCONJ
# was		was		AUX		CCONJ
# won		won		VERB		CCONJ
# by		by		ADP		CCONJ
# the		the		DET		CCONJ
# west		west		PROPN		CCONJ
# indies		indies		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# who		who		PRON		DET
# defeated		defeated		VERB		CCONJ
# australia		australia		PROPN		CCONJ
# by		by		ADP		CCONJ
# 17		17		NUM		CCONJ
# runs		runs		NOUN		DET
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# final		final		ADJ		CCONJ
# at		at		ADP		CCONJ
# lord		lord		PROPN		DET
# 's		's		PART		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15318
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# society		society		PROPN		DET
# to		to		PART		CCONJ
# encourage		encourage		VERB		DET
# studies		studies		PROPN		CCONJ
# at		at		ADP		CCONJ
# home		home		NOUN		CCONJ
# was		was		AUX		CCONJ
# founded		founded		VERB		DET
# in		in		ADP		CCONJ
# 1873		1873		NUM		DET
# in		in		ADP		CCONJ
# boston		boston		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# massachusetts		massachusetts		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15319
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# ibm		ibm		PROPN		DET
# developed		developed		VERB		DET
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# several		several		ADJ		CCONJ
# companies		companies		NOUN		CCONJ
# copied		copied		VERB		DET
# ,		,		PUNCT		CCONJ
# an		an		DET		CCONJ
# autoloader		autoloader		NOUN		DET
# mechanism		mechanism		NOUN		DET
# that		that		DET		CCONJ
# could		could		VERB		CCONJ
# load		load		VERB		CCONJ
# a		a		DET		CCONJ
# stack		stack		NOUN		CCONJ
# of		of		ADP		CCONJ
# floppies		floppies		NOUN		DET
# one		one		NUM		CCONJ
# at		at		ADP		CCONJ
# a		a		DET		CCONJ
# time		time		NOUN		CCONJ
# into		into		ADP		CCONJ
# a		a		DET		CCONJ
# drive		drive		NOUN		CCONJ
# unit		unit		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15320
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# when		when		ADV		CCONJ
# asked		asked		VERB		CCONJ
# about		about		ADP		CCONJ
# the		the		DET		CCONJ
# "		"		PUNCT		CCONJ
# dk		dk		PROPN		DET
# "		"		PUNCT		CCONJ
# logo		logo		NOUN		DET
# in		in		ADP		CCONJ
# an		an		DET		CCONJ
# interview		interview		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# jello		jello		PROPN		DET
# biafra		biafra		PROPN		DET
# explained		explained		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# "		"		PUNCT		CCONJ
# ...		...		PUNCT		CCONJ
# ==============================
# sentence 15321
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# i		i		PRON		CCONJ
# wanted		wanted		VERB		CCONJ
# to		to		PART		CCONJ
# make		make		VERB		CCONJ
# sure		sure		ADJ		CCONJ
# it		it		PRON		CCONJ
# was		was		AUX		CCONJ
# something		something		PRON		CCONJ
# simple		simple		ADJ		CCONJ
# and		and		CCONJ		CCONJ
# easy		easy		ADJ		CCONJ
# to		to		PART		CCONJ
# spray-paint		spray-paint		VERB		DET
# so		so		SCONJ		CCONJ
# people		people		NOUN		CCONJ
# would		would		VERB		CCONJ
# graffiti		graffiti		VERB		CCONJ
# it		it		PRON		CCONJ
# all		all		ADV		CCONJ
# over		over		ADP		CCONJ
# the		the		DET		CCONJ
# place		place		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# then		then		ADV		DET
# i		i		PRON		CCONJ
# showed		showed		VERB		CCONJ
# it		it		PRON		CCONJ
# to		to		ADP		CCONJ
# winston		winston		PROPN		DET
# smith		smith		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15322
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# some		some		DET		CCONJ
# parkways		parkways		NOUN		DET
# ,		,		PUNCT		CCONJ
# notably		notably		ADV		CCONJ
# the		the		DET		CCONJ
# taconic		taconic		PROPN		DET
# parkway		parkway		PROPN		DET
# ,		,		PUNCT		CCONJ
# sprain		sprain		PROPN		DET
# brook		brook		PROPN		DET
# parkway		parkway		PROPN		DET
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# saw		saw		VERB		CCONJ
# mill		mill		PROPN		DET
# parkway		parkway		PROPN		DET
# have		have		AUX		CCONJ
# at-grade		at-grade		VERB		CCONJ
# intersections		intersections		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# although		although		SCONJ		CCONJ
# direct		direct		ADJ		CCONJ
# access		access		NOUN		DET
# to		to		ADP		CCONJ
# property		property		NOUN		DET
# adjacent		adjacent		ADJ		DET
# to		to		ADP		CCONJ
# the		the		DET		CCONJ
# parkways		parkways		NOUN		DET
# is		is		AUX		CCONJ
# prohibited		prohibited		VERB		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15323
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# humble		humble		ADJ		CCONJ
# brand		brand		NOUN		CCONJ
# was		was		AUX		CCONJ
# used		used		VERB		DET
# at		at		ADP		CCONJ
# texas		texas		PROPN		CCONJ
# stations		stations		NOUN		CCONJ
# for		for		ADP		CCONJ
# decades		decades		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# as		as		SCONJ		CCONJ
# those		those		DET		CCONJ
# operations		operations		NOUN		CCONJ
# were		were		AUX		CCONJ
# under		under		ADP		CCONJ
# the		the		DET		CCONJ
# direction		direction		NOUN		CCONJ
# of		of		ADP		CCONJ
# jersey		jersey		PROPN		CCONJ
# standard		standard		PROPN		DET
# affiliate		affiliate		NOUN		CCONJ
# humble		humble		PROPN		CCONJ
# oil		oil		PROPN		CCONJ
# &		&		CCONJ		DET
# refining		refining		PROPN		CCONJ
# company		company		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15324
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# group		group		NOUN		CCONJ
# was		was		AUX		CCONJ
# an		an		DET		CCONJ
# assemblage		assemblage		NOUN		DET
# of		of		ADP		CCONJ
# drivers		drivers		NOUN		CCONJ
# from		from		ADP		CCONJ
# different		different		ADJ		CCONJ
# racing		racing		NOUN		CCONJ
# disciplines		disciplines		NOUN		DET
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# formed		formed		VERB		DET
# for		for		ADP		CCONJ
# an		an		DET		CCONJ
# mtv		mtv		PROPN		DET
# reality		reality		NOUN		CCONJ
# pilot		pilot		NOUN		CCONJ
# which		which		DET		CCONJ
# was		was		AUX		CCONJ
# shot		shot		VERB		CCONJ
# at		at		ADP		CCONJ
# mazda		mazda		PROPN		DET
# raceway		raceway		PROPN		CCONJ
# laguna		laguna		PROPN		DET
# seca		seca		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15325
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# who		who		PRON		DET
# regard		regard		VERB		CCONJ
# a		a		DET		CCONJ
# bmi		bmi		PROPN		DET
# of		of		ADP		CCONJ
# less		less		ADJ		CCONJ
# than		than		SCONJ		CCONJ
# 18.5		18.5		NUM		DET
# as		as		SCONJ		CCONJ
# underweight		underweight		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# may		may		VERB		CCONJ
# indicate		indicate		VERB		CCONJ
# malnutrition		malnutrition		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# an		an		DET		CCONJ
# eating		eating		VERB		DET
# disorder		disorder		NOUN		DET
# ,		,		PUNCT		CCONJ
# or		or		CCONJ		CCONJ
# other		other		ADJ		CCONJ
# health		health		NOUN		CCONJ
# problems		problems		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# while		while		SCONJ		CCONJ
# a		a		DET		CCONJ
# bmi		bmi		PROPN		DET
# greater		greater		ADJ		CCONJ
# than		than		SCONJ		CCONJ
# 25		25		NUM		CCONJ
# is		is		AUX		CCONJ
# considered		considered		VERB		CCONJ
# overweight		overweight		ADJ		CCONJ
# and		and		CCONJ		CCONJ
# above		above		ADP		CCONJ
# 30		30		NUM		CCONJ
# is		is		AUX		CCONJ
# considered		considered		VERB		CCONJ
# obese		obese		ADJ		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15326
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# in		in		ADP		CCONJ
# 2005		2005		NUM		CCONJ
# ,		,		PUNCT		CCONJ
# shane		shane		PROPN		CCONJ
# black		black		PROPN		CCONJ
# directed		directed		VERB		CCONJ
# kiss		kiss		PROPN		DET
# kiss		kiss		PROPN		DET
# bang		bang		PROPN		DET
# bang		bang		PROPN		DET
# ,		,		PUNCT		CCONJ
# basing		basing		VERB		DET
# his		his		DET		CCONJ
# screenplay		screenplay		NOUN		CCONJ
# in		in		ADP		CCONJ
# part		part		NOUN		CCONJ
# on		on		ADP		CCONJ
# a		a		DET		CCONJ
# crime		crime		NOUN		CCONJ
# novel		novel		NOUN		DET
# by		by		ADP		CCONJ
# brett		brett		PROPN		CCONJ
# halliday		halliday		PROPN		DET
# ,		,		PUNCT		CCONJ
# who		who		PRON		DET
# published		published		VERB		DET
# his		his		DET		CCONJ
# first		first		ADJ		CCONJ
# stories		stories		NOUN		CCONJ
# back		back		ADV		CCONJ
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# 1920s		1920s		NUM		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15327
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# he		he		PRON		CCONJ
# died		died		VERB		CCONJ
# on		on		ADP		CCONJ
# june		june		PROPN		CCONJ
# 30		30		NUM		CCONJ
# ,		,		PUNCT		CCONJ
# 2001		2001		NUM		DET
# at		at		ADP		CCONJ
# his		his		DET		CCONJ
# home		home		NOUN		CCONJ
# in		in		ADP		CCONJ
# nashville		nashville		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15328
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# but		but		CCONJ		CCONJ
# ruth		ruth		PROPN		DET
# caught		caught		VERB		CCONJ
# gehrig		gehrig		PROPN		DET
# (		(		PUNCT		DET
# who		who		PRON		DET
# would		would		VERB		CCONJ
# finish		finish		VERB		CCONJ
# with		with		ADP		CCONJ
# 47		47		NUM		CCONJ
# )		)		PUNCT		DET
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# then		then		ADV		DET
# had		had		AUX		CCONJ
# a		a		DET		CCONJ
# remarkable		remarkable		ADJ		CCONJ
# last		last		ADJ		CCONJ
# leg		leg		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# season		season		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# hitting		hitting		VERB		CCONJ
# 17		17		NUM		CCONJ
# home		home		NOUN		CCONJ
# runs		runs		NOUN		DET
# in		in		ADP		CCONJ
# september		september		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15329
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# they		they		PRON		CCONJ
# fortified		fortified		VERB		DET
# their		their		DET		CCONJ
# positions		positions		NOUN		CCONJ
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# factory		factory		NOUN		CCONJ
# districts		districts		NOUN		DET
# and		and		CCONJ		CCONJ
# the		the		DET		CCONJ
# soviets		soviets		PROPN		DET
# encountered		encountered		VERB		DET
# almost		almost		ADV		CCONJ
# the		the		DET		CCONJ
# same		same		ADJ		CCONJ
# tooth-and-nail		tooth-and-nail		NOUN		DET
# ferocity		ferocity		NOUN		CCONJ
# that		that		SCONJ		CCONJ
# they		they		PRON		CCONJ
# themselves		themselves		PRON		CCONJ
# displayed		displayed		VERB		CCONJ
# a		a		DET		CCONJ
# month		month		NOUN		CCONJ
# earlier		earlier		ADV		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15330
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# although		although		SCONJ		CCONJ
# critically		critically		ADV		CCONJ
# acclaimed		acclaimed		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# magazine		magazine		NOUN		CCONJ
# was		was		AUX		CCONJ
# short		short		ADV		CCONJ
# lived		lived		VERB		DET
# and		and		CCONJ		CCONJ
# ended		ended		VERB		CCONJ
# its		its		DET		CCONJ
# publication		publication		NOUN		CCONJ
# in		in		ADP		CCONJ
# 1976		1976		NUM		DET
# when		when		ADV		CCONJ
# coppola		coppola		PROPN		DET
# published		published		VERB		DET
# its		its		DET		CCONJ
# last		last		ADJ		CCONJ
# issue		issue		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15331
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# kelly		kelly		PROPN		CCONJ
# continued		continued		VERB		CCONJ
# to		to		PART		CCONJ
# make		make		VERB		CCONJ
# frequent		frequent		ADJ		DET
# tv		tv		NOUN		CCONJ
# appearances		appearances		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# in		in		ADP		CCONJ
# 1980		1980		NUM		DET
# ,		,		PUNCT		CCONJ
# appeared		appeared		VERB		CCONJ
# in		in		ADP		CCONJ
# an		an		DET		CCONJ
# acting		acting		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# dancing		dancing		VERB		DET
# role		role		NOUN		CCONJ
# opposite		opposite		ADJ		CCONJ
# olivia		olivia		PROPN		DET
# newton		newton		PROPN		CCONJ
# john		john		PROPN		CCONJ
# in		in		ADP		CCONJ
# xanadu		xanadu		PROPN		DET
# (		(		PUNCT		DET
# 1980		1980		NUM		DET
# )		)		PUNCT		DET
# ,		,		PUNCT		CCONJ
# an		an		DET		CCONJ
# expensive		expensive		ADJ		CCONJ
# theatrical		theatrical		ADJ		CCONJ
# flop		flop		NOUN		CCONJ
# which		which		DET		CCONJ
# has		has		AUX		CCONJ
# since		since		SCONJ		CCONJ
# attained		attained		VERB		DET
# a		a		DET		CCONJ
# cult		cult		NOUN		DET
# following		following		VERB		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15332
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# are		are		AUX		CCONJ
# we		we		PRON		CCONJ
# judging		judging		VERB		DET
# warhol		warhol		PROPN		DET
# 's		's		PART		CCONJ
# concept		concept		NOUN		DET
# ?		?		PUNCT		CCONJ
# ==============================
# sentence 15333
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# hurst		hurst		PROPN		DET
# settled		settled		VERB		CCONJ
# into		into		ADP		CCONJ
# international		international		ADJ		CCONJ
# football		football		NOUN		DET
# quickly		quickly		ADV		CCONJ
# but		but		CCONJ		CCONJ
# as		as		SCONJ		CCONJ
# the		the		DET		CCONJ
# world		world		PROPN		CCONJ
# cup		cup		PROPN		CCONJ
# approached		approached		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# it		it		PRON		CCONJ
# seemed		seemed		VERB		CCONJ
# clear		clear		ADJ		CCONJ
# that		that		SCONJ		CCONJ
# his		his		DET		CCONJ
# inclusion		inclusion		NOUN		CCONJ
# in		in		ADP		CCONJ
# ramsey		ramsey		PROPN		DET
# 's		's		PART		CCONJ
# squad		squad		NOUN		CCONJ
# of		of		ADP		CCONJ
# 22		22		NUM		CCONJ
# would		would		VERB		CCONJ
# merely		merely		ADV		DET
# be		be		AUX		CCONJ
# as		as		SCONJ		CCONJ
# a		a		DET		CCONJ
# different		different		ADJ		CCONJ
# option		option		NOUN		CCONJ
# to		to		ADP		CCONJ
# the		the		DET		CCONJ
# first		first		ADJ		CCONJ
# choice		choice		NOUN		CCONJ
# partnership		partnership		NOUN		CCONJ
# of		of		ADP		CCONJ
# jimmy		jimmy		PROPN		CCONJ
# greaves		greaves		PROPN		DET
# and		and		CCONJ		CCONJ
# roger		roger		PROPN		CCONJ
# hunt		hunt		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15334
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# maxentius		maxentius		PROPN		DET
# '		'		PART		CCONJ
# support		support		NOUN		CCONJ
# continued		continued		VERB		CCONJ
# to		to		PART		CCONJ
# weaken		weaken		VERB		CCONJ
# :		:		PUNCT		CCONJ
# at		at		ADP		CCONJ
# chariot		chariot		NOUN		DET
# races		races		NOUN		CCONJ
# on		on		ADP		CCONJ
# 27		27		NUM		CCONJ
# october		october		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# crowd		crowd		NOUN		CCONJ
# openly		openly		ADV		CCONJ
# taunted		taunted		VERB		CCONJ
# maxentius		maxentius		PROPN		DET
# ,		,		PUNCT		CCONJ
# shouting		shouting		VERB		CCONJ
# that		that		SCONJ		CCONJ
# constantine		constantine		PROPN		DET
# was		was		AUX		CCONJ
# invincible		invincible		ADJ		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15335
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# also		also		ADV		DET
# located		located		VERB		DET
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# city		city		NOUN		CCONJ
# centre		centre		NOUN		DET
# are		are		AUX		CCONJ
# the		the		DET		CCONJ
# botanical		botanical		PROPN		DET
# gardens		gardens		PROPN		DET
# particularly		particularly		ADV		CCONJ
# noted		noted		VERB		CCONJ
# for		for		ADP		CCONJ
# their		their		DET		CCONJ
# large		large		ADJ		CCONJ
# complex		complex		NOUN		CCONJ
# of		of		ADP		CCONJ
# 19th		19th		ADJ		CCONJ
# century		century		NOUN		CCONJ
# greenhouses		greenhouses		NOUN		CCONJ
# donated		donated		VERB		DET
# by		by		ADP		CCONJ
# carlsberg		carlsberg		PROPN		DET
# founder		founder		NOUN		DET
# j.		j.		PROPN		CCONJ
# c.		c.		PROPN		CCONJ
# jacobsen		jacobsen		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15336
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# law		law		PROPN		CCONJ
# does		does		AUX		CCONJ
# not		not		PART		CCONJ
# usually		usually		ADV		CCONJ
# accept		accept		VERB		CCONJ
# the		the		DET		CCONJ
# agent		agent		NOUN		CCONJ
# 's		's		PART		CCONJ
# self-punishment		self-punishment		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# but		but		CCONJ		CCONJ
# some		some		DET		CCONJ
# ancient		ancient		ADJ		DET
# codes		codes		NOUN		DET
# did		did		AUX		CCONJ
# :		:		PUNCT		CCONJ
# in		in		ADP		CCONJ
# athens		athens		PROPN		DET
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# accused		accused		VERB		CCONJ
# could		could		VERB		CCONJ
# propose		propose		VERB		DET
# their		their		DET		CCONJ
# own		own		ADJ		CCONJ
# remedy		remedy		NOUN		DET
# ,		,		PUNCT		CCONJ
# which		which		DET		CCONJ
# could		could		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# in		in		ADP		CCONJ
# fact		fact		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# be		be		AUX		CCONJ
# a		a		DET		CCONJ
# reward		reward		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# while		while		SCONJ		CCONJ
# the		the		DET		CCONJ
# accuser		accuser		NOUN		DET
# proposed		proposed		VERB		CCONJ
# another		another		DET		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# the		the		DET		CCONJ
# jury		jury		NOUN		CCONJ
# chose		chose		VERB		CCONJ
# something		something		PRON		CCONJ
# in-between		in-between		VERB		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15337
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# henry		henry		PROPN		CCONJ
# kissinger		kissinger		PROPN		DET
# received		received		VERB		DET
# his		his		DET		CCONJ
# b.a.		b.a.		PROPN		DET
# degree		degree		NOUN		CCONJ
# summa		summa		PROPN		DET
# cum		cum		PROPN		DET
# laude		laude		NOUN		DET
# at		at		ADP		CCONJ
# harvard		harvard		PROPN		CCONJ
# college		college		PROPN		DET
# in		in		ADP		CCONJ
# 1950		1950		NUM		DET
# ,		,		PUNCT		CCONJ
# where		where		ADV		CCONJ
# he		he		PRON		CCONJ
# studied		studied		VERB		CCONJ
# under		under		ADP		CCONJ
# william		william		PROPN		CCONJ
# yandell		yandell		PROPN		DET
# elliott		elliott		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15338
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# he		he		PRON		CCONJ
# designed		designed		VERB		CCONJ
# many		many		ADJ		CCONJ
# buildings		buildings		NOUN		CCONJ
# in		in		ADP		CCONJ
# rome		rome		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# which		which		DET		CCONJ
# included		included		VERB		CCONJ
# work		work		NOUN		CCONJ
# at		at		ADP		CCONJ
# the		the		DET		CCONJ
# villa		villa		PROPN		DET
# giulia		giulia		PROPN		DET
# complex		complex		NOUN		CCONJ
# (		(		PUNCT		DET
# in		in		ADP		CCONJ
# collaboration		collaboration		NOUN		DET
# with		with		ADP		CCONJ
# vignola		vignola		PROPN		DET
# and		and		CCONJ		CCONJ
# vasari		vasari		PROPN		DET
# )		)		PUNCT		DET
# ,		,		PUNCT		CCONJ
# also		also		ADV		DET
# at		at		ADP		CCONJ
# lucca		lucca		PROPN		DET
# and		and		CCONJ		CCONJ
# florence		florence		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15339
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# karaites		karaites		NOUN		DET
# use		use		VERB		CCONJ
# the		the		DET		CCONJ
# lunar		lunar		ADJ		DET
# month		month		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# the		the		DET		CCONJ
# solar		solar		ADJ		CCONJ
# year		year		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# but		but		CCONJ		CCONJ
# the		the		DET		CCONJ
# karaite		karaite		PROPN		DET
# calendar		calendar		NOUN		DET
# differs		differs		VERB		DET
# from		from		ADP		CCONJ
# the		the		DET		CCONJ
# rabbinic		rabbinic		ADJ		DET
# calendar		calendar		NOUN		DET
# in		in		ADP		CCONJ
# a		a		DET		CCONJ
# number		number		NOUN		CCONJ
# of		of		ADP		CCONJ
# ways		ways		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15340
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# civic		civic		PROPN		CCONJ
# and		and		CCONJ		CCONJ
# the		the		DET		CCONJ
# accord		accord		PROPN		CCONJ
# were		were		AUX		CCONJ
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# top		top		ADJ		CCONJ
# five		five		NUM		CCONJ
# list		list		NOUN		CCONJ
# of		of		ADP		CCONJ
# sales		sales		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15341
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# this		this		DET		CCONJ
# phallus		phallus		NOUN		DET
# symbolizes		symbolizes		VERB		DET
# the		the		DET		CCONJ
# model		model		NOUN		DET
# 's		's		PART		CCONJ
# obsession		obsession		NOUN		DET
# with		with		ADP		CCONJ
# the		the		DET		CCONJ
# penis		penis		NOUN		DET
# and		and		CCONJ		CCONJ
# her		her		DET		CCONJ
# lifelong		lifelong		ADJ		DET
# quest		quest		NOUN		CCONJ
# to		to		PART		CCONJ
# achieve		achieve		VERB		CCONJ
# vaginal		vaginal		ADJ		CCONJ
# orgasm		orgasm		NOUN		DET
# ,		,		PUNCT		CCONJ
# with		with		ADP		CCONJ
# the		the		DET		CCONJ
# help		help		NOUN		CCONJ
# of		of		ADP		CCONJ
# sigmund		sigmund		PROPN		DET
# freud		freud		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15342
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# he		he		PRON		CCONJ
# probably		probably		ADV		CCONJ
# returned		returned		VERB		CCONJ
# to		to		ADP		CCONJ
# nicomedia		nicomedia		PROPN		DET
# for		for		ADP		CCONJ
# the		the		DET		CCONJ
# winter		winter		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15343
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# christianity		christianity		PROPN		DET
# has		has		AUX		CCONJ
# used		used		VERB		DET
# symbolism		symbolism		NOUN		CCONJ
# from		from		ADP		CCONJ
# its		its		DET		CCONJ
# very		very		ADJ		CCONJ
# beginnings		beginnings		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15344
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# dec		dec		PROPN		DET
# also		also		ADV		DET
# produced		produced		VERB		CCONJ
# a		a		DET		CCONJ
# pc-like		pc-like		PROPN		DET
# alpha		alpha		NOUN		DET
# workstation		workstation		NOUN		DET
# with		with		ADP		CCONJ
# an		an		DET		CCONJ
# eisa		eisa		PROPN		DET
# bus		bus		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# decpc		decpc		PROPN		DET
# axp		axp		PROPN		DET
# 150		150		NUM		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15345
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# since		since		SCONJ		CCONJ
# early		early		ADJ		CCONJ
# 2009		2009		NUM		DET
# ,		,		PUNCT		CCONJ
# helsinki		helsinki		PROPN		DET
# has		has		AUX		CCONJ
# begun		begun		VERB		CCONJ
# to		to		PART		CCONJ
# contemplate		contemplate		VERB		CCONJ
# a		a		DET		CCONJ
# possible		possible		ADJ		CCONJ
# merger		merger		NOUN		CCONJ
# with		with		ADP		CCONJ
# vantaa		vantaa		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15346
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# however		however		ADV		CCONJ
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# variance		variance		NOUN		DET
# between		between		ADP		CCONJ
# methods		methods		NOUN		DET
# results		results		NOUN		CCONJ
# in		in		ADP		CCONJ
# differing		differing		VERB		CCONJ
# recognition		recognition		NOUN		DET
# for		for		ADP		CCONJ
# the		the		DET		CCONJ
# 1887		1887		NUM		DET
# national		national		PROPN		CCONJ
# league		league		PROPN		CCONJ
# batting		batting		NOUN		DET
# champion		champion		NOUN		CCONJ
# ;		;		PUNCT		CCONJ
# cap		cap		PROPN		CCONJ
# anson		anson		PROPN		DET
# would		would		VERB		CCONJ
# be		be		AUX		CCONJ
# recognized		recognized		VERB		DET
# ,		,		PUNCT		CCONJ
# with		with		ADP		CCONJ
# his		his		DET		CCONJ
# .421		.421		NUM		DET
# average		average		NOUN		DET
# ,		,		PUNCT		CCONJ
# if		if		SCONJ		CCONJ
# walks		walks		NOUN		DET
# are		are		AUX		CCONJ
# included		included		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# but		but		CCONJ		CCONJ
# sam		sam		PROPN		CCONJ
# thompson		thompson		PROPN		CCONJ
# would		would		VERB		CCONJ
# be		be		AUX		CCONJ
# the		the		DET		CCONJ
# champion		champion		NOUN		CCONJ
# at		at		ADP		CCONJ
# .372		.372		NUM		DET
# if		if		SCONJ		CCONJ
# they		they		PRON		CCONJ
# are		are		AUX		CCONJ
# not		not		PART		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15347
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# apollo		apollo		PROPN		DET
# 9		9		NUM		CCONJ
# was		was		AUX		CCONJ
# the		the		DET		CCONJ
# first		first		ADJ		CCONJ
# manned		manned		ADJ		CCONJ
# flight		flight		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# command/service		command/service		PROPN		DET
# module		module		PROPN		DET
# (		(		PUNCT		DET
# csm		csm		PROPN		DET
# )		)		PUNCT		DET
# along		along		ADP		CCONJ
# with		with		ADP		CCONJ
# the		the		DET		CCONJ
# lunar		lunar		PROPN		DET
# module		module		PROPN		DET
# (		(		PUNCT		DET
# lm		lm		PROPN		DET
# )		)		PUNCT		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15348
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# zulu		zulu		PROPN		DET
# had		had		AUX		CCONJ
# greater		greater		ADJ		CCONJ
# numbers		numbers		NOUN		DET
# than		than		SCONJ		CCONJ
# their		their		DET		CCONJ
# opponents		opponents		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# but		but		CCONJ		CCONJ
# greater		greater		ADJ		CCONJ
# numbers		numbers		NOUN		DET
# massed		massed		VERB		CCONJ
# together		together		ADV		CCONJ
# simply		simply		ADV		CCONJ
# presented		presented		VERB		CCONJ
# yet		yet		ADV		CCONJ
# more		more		ADV		CCONJ
# lucrative		lucrative		ADJ		CCONJ
# ,		,		PUNCT		CCONJ
# easy		easy		ADJ		CCONJ
# shooting		shooting		NOUN		CCONJ
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# age		age		NOUN		CCONJ
# of		of		ADP		CCONJ
# modern		modern		ADJ		CCONJ
# firearms		firearms		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# artillery		artillery		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15349
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# holland		holland		PROPN		CCONJ
# was		was		AUX		CCONJ
# divided		divided		VERB		CCONJ
# into		into		ADP		CCONJ
# the		the		DET		CCONJ
# present		present		ADJ		CCONJ
# provinces		provinces		NOUN		DET
# north		north		PROPN		CCONJ
# holland		holland		PROPN		CCONJ
# and		and		CCONJ		CCONJ
# south		south		PROPN		CCONJ
# holland		holland		PROPN		CCONJ
# in		in		ADP		CCONJ
# 1840		1840		NUM		DET
# ,		,		PUNCT		CCONJ
# after		after		ADP		CCONJ
# the		the		DET		CCONJ
# belgian		belgian		PROPN		DET
# revolution		revolution		PROPN		CCONJ
# of		of		ADP		CCONJ
# 1830		1830		NUM		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15350
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# she		she		PRON		CCONJ
# worked		worked		VERB		DET
# as		as		SCONJ		CCONJ
# a		a		DET		CCONJ
# management		management		NOUN		DET
# trainee		trainee		NOUN		DET
# for		for		ADP		CCONJ
# kmart		kmart		PROPN		DET
# in		in		ADP		CCONJ
# 1981		1981		NUM		DET
# but		but		CCONJ		CCONJ
# quit		quit		VERB		DET
# after		after		ADP		CCONJ
# a		a		DET		CCONJ
# few		few		ADJ		CCONJ
# months		months		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# entered		entered		VERB		CCONJ
# some		some		DET		CCONJ
# potentially		potentially		ADV		CCONJ
# lucrative		lucrative		ADJ		CCONJ
# beauty		beauty		NOUN		DET
# pageants		pageants		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15351
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# seydlitz		seydlitz		PROPN		DET
# ,		,		PUNCT		CCONJ
# critically		critically		ADV		CCONJ
# damaged		damaged		ADJ		CCONJ
# and		and		CCONJ		CCONJ
# very		very		ADV		CCONJ
# nearly		nearly		ADV		CCONJ
# sinking		sinking		VERB		DET
# ,		,		PUNCT		CCONJ
# barely		barely		ADV		CCONJ
# survived		survived		VERB		CCONJ
# the		the		DET		CCONJ
# return		return		NOUN		CCONJ
# voyage		voyage		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# after		after		ADP		CCONJ
# grounding		grounding		VERB		DET
# and		and		CCONJ		CCONJ
# taking		taking		VERB		CCONJ
# on		on		ADP		CCONJ
# even		even		ADV		CCONJ
# more		more		ADJ		CCONJ
# water		water		NOUN		DET
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# evening		evening		NOUN		CCONJ
# of		of		ADP		CCONJ
# 1		1		NUM		CCONJ
# june		june		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# had		had		AUX		CCONJ
# to		to		PART		CCONJ
# be		be		AUX		CCONJ
# assisted		assisted		VERB		DET
# in		in		ADP		CCONJ
# to		to		PART		CCONJ
# port		port		VERB		CCONJ
# stern		stern		ADJ		CCONJ
# first		first		ADV		CCONJ
# ,		,		PUNCT		CCONJ
# where		where		ADV		CCONJ
# she		she		PRON		CCONJ
# dropped		dropped		VERB		CCONJ
# anchor		anchor		NOUN		DET
# at		at		ADP		CCONJ
# 07:30		07:30		NUM		DET
# on		on		ADP		CCONJ
# the		the		DET		CCONJ
# morning		morning		NOUN		CCONJ
# of		of		ADP		CCONJ
# 2		2		NUM		CCONJ
# june		june		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15352
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# haiti		haiti		PROPN		CCONJ
# is		is		AUX		CCONJ
# the		the		DET		CCONJ
# poorest		poorest		ADJ		CCONJ
# country		country		NOUN		CCONJ
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# americas		americas		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15353
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# largest		largest		ADJ		CCONJ
# share		share		NOUN		CCONJ
# holders		holders		NOUN		DET
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# adb		adb		PROPN		DET
# are		are		AUX		CCONJ
# japan		japan		PROPN		DET
# and		and		CCONJ		CCONJ
# usa		usa		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# ==============================
# sentence 15354
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# each		each		DET		CCONJ
# holding		holding		VERB		CCONJ
# 15.57		15.57		NUM		DET
# %		%		NOUN		DET
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# shares		shares		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15355
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# since		since		SCONJ		CCONJ
# his		his		DET		CCONJ
# mother		mother		NOUN		DET
# was		was		AUX		CCONJ
# widowed		widowed		VERB		DET
# ,		,		PUNCT		CCONJ
# wankel		wankel		PROPN		DET
# received		received		VERB		DET
# no		no		DET		CCONJ
# university		university		NOUN		CCONJ
# education		education		NOUN		DET
# or		or		CCONJ		CCONJ
# even		even		ADV		CCONJ
# an		an		DET		CCONJ
# apprenticeship		apprenticeship		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15356
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# while		while		SCONJ		CCONJ
# this		this		DET		CCONJ
# is		is		AUX		CCONJ
# an		an		DET		CCONJ
# appealing		appealing		VERB		CCONJ
# concept		concept		NOUN		DET
# ,		,		PUNCT		CCONJ
# there		there		PRON		CCONJ
# are		are		AUX		CCONJ
# problems		problems		NOUN		CCONJ
# with		with		ADP		CCONJ
# wright		wright		PROPN		CCONJ
# 's		's		PART		CCONJ
# solution		solution		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15357
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# "		"		PUNCT		CCONJ
# there		there		PRON		CCONJ
# 's		's		AUX		CCONJ
# no		no		DET		CCONJ
# mistake		mistake		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# boy		boy		INTJ		DET
# ,		,		PUNCT		CCONJ
# just		just		ADV		CCONJ
# sign		sign		VERB		CCONJ
# it		it		PRON		CCONJ
# and		and		CCONJ		CCONJ
# return		return		VERB		CCONJ
# it		it		PRON		CCONJ
# "		"		PUNCT		CCONJ
# ,		,		PUNCT		CCONJ
# parker		parker		PROPN		DET
# directed		directed		VERB		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15358
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# 1964		1964		NUM		DET
# --		--		PUNCT		CCONJ
# 1965		1965		NUM		DET
# surveys		surveys		NOUN		DET
# concentrated		concentrated		VERB		CCONJ
# on		on		ADP		CCONJ
# a		a		DET		CCONJ
# northerly		northerly		ADJ		DET
# route		route		NOUN		CCONJ
# that		that		DET		CCONJ
# left		left		VERB		CCONJ
# the		the		DET		CCONJ
# english		english		ADJ		DET
# coast		coast		NOUN		CCONJ
# at		at		ADP		CCONJ
# dover		dover		PROPN		CCONJ
# harbour		harbour		NOUN		CCONJ
# ;		;		PUNCT		CCONJ
# using		using		VERB		DET
# 70		70		NUM		CCONJ
# boreholes		boreholes		NOUN		DET
# ,		,		PUNCT		CCONJ
# an		an		DET		CCONJ
# area		area		NOUN		CCONJ
# of		of		ADP		CCONJ
# deeply		deeply		ADV		CCONJ
# weathered		weathered		VERB		DET
# rock		rock		NOUN		CCONJ
# with		with		ADP		CCONJ
# high		high		ADJ		CCONJ
# permeability		permeability		NOUN		CCONJ
# was		was		AUX		CCONJ
# located		located		VERB		DET
# just		just		ADV		CCONJ
# south		south		ADV		CCONJ
# of		of		ADP		CCONJ
# dover		dover		PROPN		CCONJ
# harbour		harbour		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15359
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# a		a		DET		CCONJ
# similar		similar		ADJ		CCONJ
# technology		technology		NOUN		CCONJ
# called		called		VERB		CCONJ
# naplps		naplps		PROPN		DET
# was		was		AUX		CCONJ
# also		also		ADV		DET
# considered		considered		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# although		although		SCONJ		CCONJ
# it		it		PRON		CCONJ
# became		became		VERB		DET
# the		the		DET		CCONJ
# underlying		underlying		VERB		CCONJ
# graphics		graphics		NOUN		DET
# technology		technology		NOUN		CCONJ
# behind		behind		ADP		CCONJ
# the		the		DET		CCONJ
# prodigy		prodigy		PROPN		DET
# service		service		NOUN		DET
# ,		,		PUNCT		CCONJ
# it		it		PRON		CCONJ
# never		never		ADV		CCONJ
# gained		gained		VERB		CCONJ
# popularity		popularity		NOUN		DET
# in		in		ADP		CCONJ
# the		the		DET		CCONJ
# bbs		bbs		PROPN		DET
# market		market		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15360
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# stadium		stadium		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# which		which		DET		CCONJ
# is		is		AUX		CCONJ
# owned		owned		VERB		CCONJ
# directly		directly		ADV		CCONJ
# by		by		ADP		CCONJ
# the		the		DET		CCONJ
# club		club		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# was		was		AUX		CCONJ
# inaugurated		inaugurated		VERB		DET
# in		in		ADP		CCONJ
# 2006		2006		NUM		CCONJ
# and		and		CCONJ		CCONJ
# replaced		replaced		VERB		DET
# the		the		DET		CCONJ
# old		old		ADJ		CCONJ
# alkmaarderhout		alkmaarderhout		PROPN		DET
# venue		venue		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15361
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# rasputin		rasputin		PROPN		DET
# was		was		AUX		CCONJ
# deeply		deeply		ADV		CCONJ
# opposed		opposed		ADJ		CCONJ
# to		to		ADP		CCONJ
# war		war		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# both		both		CCONJ		CCONJ
# from		from		ADP		CCONJ
# a		a		DET		CCONJ
# moral		moral		ADJ		CCONJ
# point		point		NOUN		CCONJ
# of		of		ADP		CCONJ
# view		view		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# as		as		SCONJ		CCONJ
# something		something		PRON		CCONJ
# which		which		DET		CCONJ
# was		was		AUX		CCONJ
# likely		likely		ADJ		CCONJ
# to		to		PART		CCONJ
# lead		lead		VERB		CCONJ
# to		to		ADP		CCONJ
# political		political		ADJ		CCONJ
# catastrophe		catastrophe		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15362
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# accompanied		accompanied		VERB		CCONJ
# by		by		ADP		CCONJ
# ismenias		ismenias		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# he		he		PRON		CCONJ
# went		went		VERB		CCONJ
# merely		merely		ADV		DET
# as		as		SCONJ		CCONJ
# a		a		DET		CCONJ
# negotiator		negotiator		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# without		without		ADP		CCONJ
# any		any		DET		CCONJ
# military		military		ADJ		CCONJ
# force		force		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# venturing		venturing		VERB		DET
# incautiously		incautiously		ADV		DET
# within		within		ADP		CCONJ
# the		the		DET		CCONJ
# power		power		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# tyrant		tyrant		NOUN		DET
# ,		,		PUNCT		CCONJ
# was		was		AUX		CCONJ
# seized		seized		VERB		CCONJ
# by		by		ADP		CCONJ
# him		him		PRON		CCONJ
# and		and		CCONJ		CCONJ
# thrown		thrown		VERB		CCONJ
# into		into		ADP		CCONJ
# prison		prison		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15363
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# kansas		kansas		PROPN		CCONJ
# city		city		PROPN		CCONJ
# mayor		mayor		NOUN		CCONJ
# harold		harold		PROPN		CCONJ
# roe		roe		PROPN		DET
# bartle		bartle		PROPN		DET
# (		(		PUNCT		DET
# nicknamed		nicknamed		VERB		DET
# "		"		PUNCT		CCONJ
# chief		chief		PROPN		CCONJ
# "		"		PUNCT		CCONJ
# )		)		PUNCT		DET
# was		was		AUX		CCONJ
# instrumental		instrumental		ADJ		CCONJ
# in		in		ADP		CCONJ
# his		his		DET		CCONJ
# city		city		NOUN		CCONJ
# 's		's		PART		CCONJ
# success		success		NOUN		CCONJ
# in		in		ADP		CCONJ
# attracting		attracting		VERB		DET
# the		the		DET		CCONJ
# team		team		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15364
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# rideau		rideau		PROPN		DET
# canal		canal		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# completed		completed		VERB		CCONJ
# in		in		ADP		CCONJ
# 1832		1832		NUM		DET
# ,		,		PUNCT		CCONJ
# connects		connects		VERB		DET
# ottawa		ottawa		PROPN		DET
# ,		,		PUNCT		CCONJ
# on		on		ADP		CCONJ
# the		the		DET		CCONJ
# ottawa		ottawa		PROPN		DET
# river		river		PROPN		DET
# to		to		ADP		CCONJ
# kingston		kingston		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# ontario		ontario		PROPN		DET
# on		on		ADP		CCONJ
# lake		lake		PROPN		DET
# ontario		ontario		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15365
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# private		private		ADJ		CCONJ
# or		or		CCONJ		CCONJ
# free		free		ADJ		DET
# servers		servers		NOUN		DET
# sometimes		sometimes		ADV		CCONJ
# charge		charge		VERB		CCONJ
# a		a		DET		CCONJ
# fee		fee		NOUN		DET
# for		for		ADP		CCONJ
# providing		providing		VERB		DET
# players		players		NOUN		CCONJ
# with		with		ADP		CCONJ
# in		in		ADP		CCONJ
# game		game		NOUN		CCONJ
# items		items		NOUN		CCONJ
# such		such		ADJ		CCONJ
# as		as		SCONJ		CCONJ
# epic		epic		ADJ		CCONJ
# sets		sets		NOUN		CCONJ
# of		of		ADP		CCONJ
# armor		armor		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# weapons		weapons		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# gold		gold		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15366
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# as		as		ADV		CCONJ
# soon		soon		ADV		CCONJ
# as		as		SCONJ		CCONJ
# the		the		DET		CCONJ
# norman		norman		PROPN		CCONJ
# threat		threat		NOUN		CCONJ
# had		had		AUX		CCONJ
# passed		passed		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# alexios		alexios		PROPN		DET
# set		set		VERB		CCONJ
# out		out		ADP		CCONJ
# to		to		PART		CCONJ
# punish		punish		VERB		CCONJ
# the		the		DET		CCONJ
# rebels		rebels		NOUN		DET
# and		and		CCONJ		CCONJ
# deserters		deserters		NOUN		DET
# ,		,		PUNCT		CCONJ
# confiscating		confiscating		VERB		DET
# their		their		DET		CCONJ
# lands		lands		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15367
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# ascetics		ascetics		PROPN		DET
# of		of		ADP		CCONJ
# ...
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# his		his		DET		CCONJ
# contributions		contributions		NOUN		CCONJ
# to		to		ADP		CCONJ
# observational		observational		ADJ		DET
# astronomy		astronomy		NOUN		DET
# include		include		VERB		CCONJ
# the		the		DET		CCONJ
# telescopic		telescopic		ADJ		DET
# confirmation		confirmation		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# phases		phases		NOUN		DET
# of		of		ADP		CCONJ
# venus		venus		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# discovery		discovery		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# four		four		NUM		CCONJ
# largest		largest		ADJ		CCONJ
# satellites		satellites		NOUN		DET
# of		of		ADP		CCONJ
# jupiter		jupiter		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# the		the		DET		CCONJ
# observation		observation		NOUN		DET
# and		and		CCONJ		CCONJ
# analysis		analysis		NOUN		CCONJ
# of		of		ADP		CCONJ
# sunspots		sunspots		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15455
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# (		(		PUNCT		DET
# much		much		ADV		CCONJ
# later		later		ADV		CCONJ
# ,		,		PUNCT		CCONJ
# questions		questions		NOUN		CCONJ
# were		were		AUX		CCONJ
# raised		raised		VERB		CCONJ
# whether		whether		SCONJ		CCONJ
# the		the		DET		CCONJ
# measurements		measurements		NOUN		DET
# were		were		AUX		CCONJ
# accurate		accurate		ADJ		DET
# enough		enough		ADV		CCONJ
# to		to		PART		CCONJ
# support		support		VERB		CCONJ
# einstein		einstein		PROPN		DET
# 's		's		PART		CCONJ
# theory		theory		NOUN		DET
# .		.		PUNCT		CCONJ
# )		)		PUNCT		DET
# ==============================
# sentence 15456
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# if		if		SCONJ		CCONJ
# the		the		DET		CCONJ
# included		included		VERB		CCONJ
# code		code		NOUN		DET
# was		was		AUX		CCONJ
# licensed		licensed		VERB		DET
# under		under		ADP		CCONJ
# a		a		DET		CCONJ
# more		more		ADV		CCONJ
# permissive		permissive		ADJ		DET
# license		license		NOUN		DET
# such		such		ADJ		CCONJ
# as		as		SCONJ		CCONJ
# lgpl		lgpl		VERB		DET
# (		(		PUNCT		DET
# as		as		SCONJ		CCONJ
# a		a		DET		CCONJ
# library		library		NOUN		DET
# )		)		PUNCT		DET
# ,		,		PUNCT		CCONJ
# bsd		bsd		PROPN		DET
# ,		,		PUNCT		CCONJ
# or		or		CCONJ		CCONJ
# public		public		ADJ		CCONJ
# domain		domain		NOUN		DET
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# developer		developer		NOUN		DET
# would		would		VERB		CCONJ
# not		not		PART		CCONJ
# be		be		AUX		CCONJ
# entitled		entitled		VERB		DET
# to		to		ADP		CCONJ
# this		this		DET		CCONJ
# option		option		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15457
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# badminton		badminton		PROPN		DET
# world		world		PROPN		CCONJ
# federation		federation		PROPN		DET
# (		(		PUNCT		DET
# bwf		bwf		PROPN		DET
# )		)		PUNCT		DET
# is		is		AUX		CCONJ
# the		the		DET		CCONJ
# internationally		internationally		ADV		DET
# recognized		recognized		VERB		DET
# governing		governing		VERB		DET
# body		body		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# sport		sport		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15458
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# hungarian		hungarian		ADJ		DET
# football		football		NOUN		DET
# is		is		AUX		CCONJ
# known		known		VERB		CCONJ
# for		for		ADP		CCONJ
# one		one		NUM		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# most		most		ADV		CCONJ
# formidable		formidable		ADJ		CCONJ
# and		and		CCONJ		CCONJ
# influential		influential		ADJ		CCONJ
# sides		sides		NOUN		CCONJ
# in		in		ADP		CCONJ
# football		football		NOUN		DET
# history		history		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# which		which		DET		CCONJ
# revolutionized		revolutionized		VERB		DET
# the		the		DET		CCONJ
# play		play		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# game		game		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15459
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# csirac		csirac		PROPN		CCONJ
# was		was		AUX		CCONJ
# never		never		ADV		CCONJ
# recorded		recorded		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# but		but		CCONJ		CCONJ
# the		the		DET		CCONJ
# music		music		NOUN		CCONJ
# played		played		VERB		CCONJ
# was		was		AUX		CCONJ
# accurately		accurately		ADV		DET
# reconstructed		reconstructed		VERB		DET
# (		(		PUNCT		DET
# reference		reference		NOUN		DET
# 12		12		NUM		CCONJ
# )		)		PUNCT		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15460
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# beaver		beaver		NOUN		DET
# is		is		AUX		CCONJ
# also		also		ADV		DET
# the		the		DET		CCONJ
# symbol		symbol		NOUN		DET
# of		of		ADP		CCONJ
# many		many		ADJ		CCONJ
# units		units		NOUN		DET
# and		and		CCONJ		CCONJ
# organizations		organizations		NOUN		CCONJ
# within		within		ADP		CCONJ
# the		the		DET		CCONJ
# canadian		canadian		PROPN		DET
# forces		forces		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# such		such		ADJ		CCONJ
# as		as		SCONJ		CCONJ
# on		on		ADP		CCONJ
# the		the		DET		CCONJ
# cap		cap		NOUN		CCONJ
# badges		badges		NOUN		DET
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# royal		royal		PROPN		CCONJ
# 22		22		NUM		CCONJ
# e		e		NOUN		CCONJ
# régiment		régiment		PROPN		DET
# and		and		CCONJ		CCONJ
# the		the		DET		CCONJ
# canadian		canadian		PROPN		DET
# military		military		PROPN		CCONJ
# engineers		engineers		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15461
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# more		more		ADJ		CCONJ
# than		than		SCONJ		CCONJ
# 40		40		NUM		CCONJ
# percent		percent		NOUN		CCONJ
# of		of		ADP		CCONJ
# all		all		DET		CCONJ
# us		us		PROPN		CCONJ
# wheat		wheat		NOUN		DET
# exports		exports		NOUN		CCONJ
# are		are		AUX		CCONJ
# barged		barged		VERB		DET
# on		on		ADP		CCONJ
# the		the		DET		CCONJ
# columbia		columbia		PROPN		DET
# river		river		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15462
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# a		a		DET		CCONJ
# war		war		NOUN		CCONJ
# with		with		ADP		CCONJ
# scotland		scotland		PROPN		DET
# ,		,		PUNCT		CCONJ
# at		at		ADP		CCONJ
# first		first		ADV		CCONJ
# successful		successful		ADJ		CCONJ
# ,		,		PUNCT		CCONJ
# ended		ended		VERB		CCONJ
# with		with		ADP		CCONJ
# military		military		ADJ		CCONJ
# withdrawal		withdrawal		NOUN		CCONJ
# from		from		ADP		CCONJ
# there		there		ADV		CCONJ
# and		and		CCONJ		CCONJ
# boulogne-sur-mer		boulogne-sur-mer		PROPN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15463
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# they		they		PRON		CCONJ
# were		were		AUX		CCONJ
# suspected		suspected		VERB		CCONJ
# of		of		ADP		CCONJ
# being		being		AUX		CCONJ
# quartodecimans		quartodecimans		PROPN		DET
# ,		,		PUNCT		CCONJ
# unjustly		unjustly		ADV		CCONJ
# because		because		SCONJ		CCONJ
# they		they		PRON		CCONJ
# always		always		ADV		CCONJ
# kept		kept		VERB		CCONJ
# easter		easter		PROPN		DET
# on		on		ADP		CCONJ
# a		a		DET		CCONJ
# sunday		sunday		PROPN		CCONJ
# ,		,		PUNCT		CCONJ
# although		although		SCONJ		CCONJ
# that		that		DET		CCONJ
# sunday		sunday		PROPN		CCONJ
# could		could		VERB		CCONJ
# be		be		AUX		CCONJ
# as		as		ADV		CCONJ
# early		early		ADV		CCONJ
# as		as		SCONJ		CCONJ
# the		the		DET		CCONJ
# fourteenth		fourteenth		ADJ		DET
# day		day		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# lunar		lunar		ADJ		DET
# month		month		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15464
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# although		although		SCONJ		CCONJ
# they		they		PRON		CCONJ
# have		have		AUX		CCONJ
# reduced		reduced		VERB		CCONJ
# the		the		DET		CCONJ
# extent		extent		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# plants		plants		NOUN		CCONJ
# and		and		CCONJ		CCONJ
# workforce		workforce		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# including		including		VERB		CCONJ
# the		the		DET		CCONJ
# sale		sale		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# main		main		ADJ		CCONJ
# site		site		NOUN		DET
# ,		,		PUNCT		CCONJ
# gkn		gkn		PROPN		DET
# operates		operates		VERB		DET
# what		what		PRON		CCONJ
# was		was		AUX		CCONJ
# once		once		ADV		CCONJ
# the		the		DET		CCONJ
# british		british		PROPN		CCONJ
# hovercraft		hovercraft		PROPN		DET
# corporation		corporation		PROPN		DET
# a		a		DET		CCONJ
# subsidiary		subsidiary		NOUN		CCONJ
# of		of		ADP		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# known		known		VERB		CCONJ
# latterly		latterly		ADV		DET
# ,		,		PUNCT		CCONJ
# when		when		ADV		CCONJ
# manufacturing		manufacturing		VERB		CCONJ
# focus		focus		NOUN		CCONJ
# changed		changed		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# as		as		SCONJ		CCONJ
# westland		westland		PROPN		DET
# aircraft		aircraft		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15465
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# selig		selig		PROPN		DET
# announced		announced		VERB		CCONJ
# in		in		ADP		CCONJ
# july		july		PROPN		DET
# 2007		2007		NUM		DET
# when		when		ADV		CCONJ
# bonds		bonds		PROPN		DET
# was		was		AUX		CCONJ
# near		near		SCONJ		CCONJ
# 755		755		NUM		DET
# home		home		NOUN		CCONJ
# runs		runs		VERB		DET
# that		that		SCONJ		CCONJ
# he		he		PRON		CCONJ
# would		would		VERB		CCONJ
# attend		attend		VERB		CCONJ
# the		the		DET		CCONJ
# games		games		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15466
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# immediately		immediately		ADV		CCONJ
# after		after		ADP		CCONJ
# the		the		DET		CCONJ
# cancellation		cancellation		NOUN		CCONJ
# was		was		AUX		CCONJ
# announced		announced		VERB		CCONJ
# ,		,		PUNCT		CCONJ
# both		both		DET		CCONJ
# edf		edf		PROPN		DET
# and		and		CCONJ		CCONJ
# the		the		DET		CCONJ
# ddt		ddt		PROPN		DET
# manufacturers		manufacturers		NOUN		DET
# filed		filed		VERB		CCONJ
# suit		suit		NOUN		CCONJ
# against		against		ADP		CCONJ
# the		the		DET		CCONJ
# epa		epa		PROPN		DET
# ,		,		PUNCT		CCONJ
# with		with		ADP		CCONJ
# the		the		DET		CCONJ
# industry		industry		NOUN		CCONJ
# seeking		seeking		VERB		CCONJ
# to		to		PART		CCONJ
# overturn		overturn		VERB		CCONJ
# the		the		DET		CCONJ
# ban		ban		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# edf		edf		PROPN		DET
# seeking		seeking		VERB		CCONJ
# a		a		DET		CCONJ
# comprehensive		comprehensive		ADJ		DET
# ban		ban		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15467
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# not		not		PART		CCONJ
# always		always		ADV		CCONJ
# does		does		AUX		CCONJ
# history		history		NOUN		CCONJ
# repeat		repeat		VERB		CCONJ
# itself		itself		PRON		CCONJ
# ,		,		PUNCT		CCONJ
# however		however		ADV		CCONJ
# ,		,		PUNCT		CCONJ
# because		because		SCONJ		CCONJ
# this		this		DET		CCONJ
# time		time		NOUN		CCONJ
# a		a		DET		CCONJ
# cabinet		cabinet		NOUN		DET
# minister		minister		NOUN		DET
# was		was		AUX		CCONJ
# able		able		ADJ		CCONJ
# to		to		PART		CCONJ
# convince		convince		VERB		CCONJ
# the		the		DET		CCONJ
# emperor		emperor		PROPN		DET
# to		to		PART		CCONJ
# exempt		exempt		VERB		DET
# cauchy		cauchy		NOUN		DET
# from		from		ADP		CCONJ
# the		the		DET		CCONJ
# oath		oath		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15468
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# anni-frid		anni-frid		PUNCT		DET
# ==============================
# sentence 15469
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# "		"		PUNCT		CCONJ
# frida		frida		PROPN		CCONJ
# "		"		PUNCT		CCONJ
# lyngstad		lyngstad		PROPN		DET
# sang		sang		VERB		CCONJ
# from		from		ADP		CCONJ
# the		the		DET		CCONJ
# age		age		NOUN		CCONJ
# of		of		ADP		CCONJ
# thirteen		thirteen		NUM		DET
# with		with		ADP		CCONJ
# various		various		ADJ		CCONJ
# dance		dance		NOUN		CCONJ
# bands		bands		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# worked		worked		VERB		DET
# mainly		mainly		ADV		CCONJ
# in		in		ADP		CCONJ
# a		a		DET		CCONJ
# jazz-oriented		jazz-oriented		ADJ		CCONJ
# cabaret		cabaret		NOUN		CCONJ
# style		style		NOUN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15470
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# in		in		ADP		CCONJ
# 1963		1963		NUM		DET
# sylvania		sylvania		PROPN		DET
# began		began		VERB		CCONJ
# full-scale		full-scale		ADJ		DET
# production		production		NOUN		CCONJ
# of		of		ADP		CCONJ
# color		color		NOUN		CCONJ
# television		television		NOUN		CCONJ
# picture		picture		NOUN		DET
# tubes		tubes		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# and		and		CCONJ		CCONJ
# within		within		ADP		CCONJ
# two		two		NUM		CCONJ
# years		years		NOUN		CCONJ
# it		it		PRON		CCONJ
# was		was		AUX		CCONJ
# supplying		supplying		VERB		DET
# color		color		NOUN		CCONJ
# tubes		tubes		NOUN		CCONJ
# for		for		ADP		CCONJ
# 18		18		NUM		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# 23		23		NUM		CCONJ
# domestic		domestic		ADJ		CCONJ
# u.s.		u.s.		PROPN		CCONJ
# television		television		NOUN		CCONJ
# manufacturers		manufacturers		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15471
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# in		in		ADP		CCONJ
# september		september		PROPN		CCONJ
# 2009		2009		NUM		DET
# ,		,		PUNCT		CCONJ
# the		the		DET		CCONJ
# building		building		NOUN		CCONJ
# was		was		AUX		CCONJ
# lit		lit		VERB		DET
# for		for		ADP		CCONJ
# one		one		NUM		CCONJ
# night		night		NOUN		CCONJ
# in		in		ADP		CCONJ
# orange		orange		ADJ		CCONJ
# colors		colors		NOUN		CCONJ
# ,		,		PUNCT		CCONJ
# in		in		ADP		CCONJ
# celebration		celebration		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# exploration		exploration		NOUN		CCONJ
# of		of		ADP		CCONJ
# manhattan		manhattan		PROPN		CCONJ
# island		island		PROPN		DET
# by		by		ADP		CCONJ
# henry		henry		PROPN		CCONJ
# hudson		hudson		PROPN		CCONJ
# 400		400		NUM		CCONJ
# years		years		NOUN		CCONJ
# earlier		earlier		ADV		CCONJ
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15472
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# implication		implication		NOUN		CCONJ
# is		is		AUX		CCONJ
# that		that		SCONJ		CCONJ
# bluetooth		bluetooth		PROPN		DET
# does		does		AUX		CCONJ
# the		the		DET		CCONJ
# same		same		ADJ		CCONJ
# with		with		ADP		CCONJ
# communications		communications		NOUN		CCONJ
# protocols		protocols		NOUN		DET
# ,		,		PUNCT		CCONJ
# uniting		uniting		VERB		DET
# them		them		PRON		CCONJ
# into		into		ADP		CCONJ
# one		one		NUM		CCONJ
# universal		universal		ADJ		DET
# standard		standard		NOUN		DET
# .		.		PUNCT		CCONJ
# ==============================
# sentence 15473
#
# token		input		gold		prediction
# ----------------------------------------------------------------------------------------------------
# the		the		DET		CCONJ
# aim		aim		NOUN		CCONJ
# of		of		ADP		CCONJ
# the		the		DET		CCONJ
# event		event		NOUN		CCONJ
# was		was		AUX		CCONJ
# to		to		PART		CCONJ
# raise		raise		VERB		CCONJ
# money		money		NOUN		CCONJ
# to		to		PART		CCONJ
# aid		aid		VERB		CCONJ
# the		the		DET		CCONJ
# starving		starving		VERB		DET
# refugees		refugees		NOUN		DET
# during		during		ADP		CCONJ
# the		the		DET		CCONJ
# bangladesh		bangladesh		PROPN		DET
# liberation		liberation		PROPN		DET
# war		war		PROPN		CCONJ
# .		.		PUNCT		CCONJ
# ==============================

# %%
exp_1 = [['Pontë', 'Incumbent', 'of', 'Haworth', 'Yorkshire', '.'],
 ['Constantine', 'called', 'the', 'bishops', 'to', 'his', 'court', ',','among', 'them','Eusebius','.']]
print(len(exp_1))
# Out:
# 2

# %%
[' '.join(exp) for exp in exp_1]
# Out:
# ['Pontë Incumbent of Haworth Yorkshire .',
#  'Constantine called the bishops to his court , among them Eusebius .']

# %%
def print_outputs(l_trainer, l_testset, l_vocabulary, l_label_vocabulary):
    arr = []
    
    inp_string = ' '.join([' '.join(s) for s in l_testset])
    spacyconll = Spacy2ConllParser()
    spacyconll.parseprint(input_str=inp_string, output_file="inp_string.conllu")
    t_testset = POSTaggingDataset("inp_string.conllu", window_size, window_shift, device=device)
    t_testset.index_dataset(l_vocabulary, l_label_vocabulary) 

    for i in range(len([' '.join(e) for e in l_testset])): 
        arri = []
        test_elem = t_testset[i]
        test_x, test_y = test_elem["inputs"], test_elem["outputs"]
        
        logits, predictions = l_trainer.predict(test_x.unsqueeze(0))
        decoded_labels = POSTaggingDataset.decode_output(logits, l_label_vocabulary)[0]

        for raw_elem, idx, label, predicted_label in zip(t_testset.get_raw_element(i), test_x.tolist(), test_y.tolist(), decoded_labels):
            if idx == 0:
                break
            arri.append(predicted_label)

        arr.append(arri)
    return arr

arr = print_outputs(bilstm_trainer, exp_1, vocabulary, label_vocabulary)
print(arr)
# Out:
# [[12, 2, 2, 2, 12, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]]
# [['PART', 'PROPN', 'PROPN', 'PROPN', 'PART', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN']]
# [[2, 12, 2, 2, 2, 12, 2, 12, 2, 2, 12, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]]
# [['PROPN', 'PART', 'PROPN', 'PROPN', 'PROPN', 'PART', 'PROPN', 'PART', 'PROPN', 'PROPN', 'PART', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN']]
# The final result:
# [['PART', 'PROPN', 'PROPN', 'PROPN', 'PART', 'PROPN'], ['PROPN', 'PART', 'PROPN', 'PROPN', 'PROPN', 'PART', 'PROPN', 'PART', 'PROPN', 'PROPN', 'PART', 'PROPN']]
